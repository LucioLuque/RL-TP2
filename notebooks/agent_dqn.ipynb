# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import gymnasium as gym
import yaml

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from utils_dqn_agent import *

# %%
with open("../config/agent_dqn_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
experiment_folder = "mountaincar"
params = config[experiment_folder]
seed = config["xtra"]["seed"]
prefill_episodes = params["prefill_episodes"]
prefill_epsilon = params["prefill_epsilon"]
prefill_path = f"../prefill_buffers/agent_dqn/{experiment_folder}/buffer_{prefill_episodes}_eps_{prefill_epsilon}.pkl"
env = gym.make("MountainCar-v0", render_mode=None)
huber = True
model_path, _ = train_dqn_agent(experiment_folder, env=env, **params, prefill_path = prefill_path, seed = seed, huber = huber)
# Out:
# Experiment ../runs/agent_dqn/mountaincar/epi_75000_buf_50000_steps_200_g_0.99_lr_0.0005_tau_0.005_eps_0.05_max_eps_1.0_decay_5e-05_batch_64_n_3_pepi_50_peps_0.2_h_True already exists.

# %%
env = gym.make("MountainCar-v0", render_mode = None)
seed = config["xtra"]["seed"]
episodes= 100
rewards, std = evaluate_dqn(model_path, env, episodes=episodes, seed = seed)
print(f"Average reward over {episodes} episodes: {rewards} ± {round(std, 2)} std")
episodes= 1000
rewards, std = evaluate_dqn(model_path, env, episodes=episodes, seed = seed)
print(f"Average reward over {episodes} episodes: {rewards} ± {round(std, 2)} std")
episodes= 10000
rewards, std = evaluate_dqn(model_path, env, episodes=episodes, seed = seed)
print(f"Average reward over {episodes} episodes: {rewards} ± {round(std, 2)} std")
# Out:
# c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\utils_dqn_agent.py:50: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   return torch.as_tensor(
# Average reward over 100 episodes: -97.25 ± 8.47 std
# Average reward over 1000 episodes: -99.004 ± 8.11 std
# Average reward over 10000 episodes: -99.167 ± 8.01 std

# %%
env = gym.make("MountainCar-v0", render_mode = "rgb_array")

experiment_name = "MountainCar_DQN"

num_episodes = 1
epsilon = 0.0
seed = config["xtra"]["seed"]

record_experiment(model_path, experiment_name, env, num_episodes, epsilon, seed)
# Out:
# c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode 1 | Total reward: -90.0
