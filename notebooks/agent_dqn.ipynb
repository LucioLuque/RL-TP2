# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'c:\Users\Lucio\miniconda3\envs\RL\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
# ...

# %%
import os
import sys
import gymnasium as gym
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator
from pathlib import Path

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from utils_dqn_agent import *

# %%
with open("../config/agent_dqn_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
experiment_folder = "mountaincar"
params = config[experiment_folder]
seed = config["xtra"]["seed"]
prefill_path = f"../prefill_buffers/agent_dqn/{experiment_folder}/buffer.pkl"
env = gym.make("MountainCar-v0")
training_results = train_dqn_agent(experiment_folder, env=env, **params, prefill_path = prefill_path, seed = seed)
# Out:
# Prefilled replay buffer with 20 successful episodes in 20 attempts.
# Training DQN:   0%|          | 0/1000 [00:00<?, ?it/s]
# c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\agent_dqn.py:101: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   return torch.as_tensor(states, dtype=torch.float32, device=self.device)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 prefill_path = f"../prefill_buffers/agent_dqn/{experiment_folder}/buffer.pkl"
#       5 env = gym.make("MountainCar-v0")
# ...
