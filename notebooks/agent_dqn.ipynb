# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import gymnasium as gym
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator
from pathlib import Path

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from utils_dqn_agent import *

# %%
with open("../config/agent_dqn_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
experiment_folder = "mountaincar"
params = config[experiment_folder]
seed = config["xtra"]["seed"]
prefill_episodes = params["prefill_episodes"]
prefill_epsilon = params["prefill_epsilon"]
prefill_path = f"../prefill_buffers/agent_dqn/{experiment_folder}/buffer_{prefill_episodes}_eps_{prefill_epsilon}.pkl"
env = gym.make("MountainCar-v0", render_mode=None)
model_path, _, training_results = train_dqn_agent(experiment_folder, env=env, **params, prefill_path = prefill_path, seed = seed)
# Out:
# Training DQN:   0%|          | 0/75000 [00:00<?, ?it/s]

# %%
env = gym.make("MountainCar-v0", render_mode = None)
seed = config["xtra"]["seed"]
episodes= 100
rewards = evaluate_dqn(model_path, env, episodes=episodes, seed = seed)
print(f"Average reward over {episodes} episodes: {rewards}")
# Out:
# Average reward over 100 episodes: -97.25

# %%
env = gym.make("MountainCar-v0", render_mode = "rgb_array")

experiment_name = "MountainCar_DQN"

num_episodes = 1
epsilon = 0.0
seed = config["xtra"]["seed"]

record_experiment(model_path, experiment_name, env, num_episodes, epsilon, seed)
# Out:
# Episode 1 | Total reward: -90.0
# /home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/gymnasium/wrappers/rendering.py:292: UserWarning: WARN: Overwriting existing videos at /home/alumno1/Documents/RL-TP2/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
