# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import gymnasium as gym
import yaml

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from utils_dqn import *

# %%
with open("../config/dqn_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
env = gym.make("CartPole-v1", render_mode = None)

print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %%
experiment_folder = "cartpole"
params = config[experiment_folder]
seed = config["xtra"]["seed"]

model_path, _, = train_dqn(experiment_folder, env, seed=seed, **params)
# Out:
# Experiment ../runs/dqn/cartpole/epi_199_buf_10000_steps_500_g_0.99_lr_0.001_target_130_eps_0.01_max_eps_1.0_decay_0.02_batch_64 already exists.

# %%
env = gym.make("CartPole-v1", render_mode = None)

success_rate, rewards_mean = evaluate_dqn(model_path, env, episodes=100, seed=seed)
print(f"Success rate: {success_rate:.2f}")
print(f"Mean rewards: {rewards_mean:.2f}")
# Out:
# c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\utils_dqn.py:50: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   return torch.as_tensor(
# Success rate: 1.00
# Mean rewards: 500.00

# %%
env = gym.make("CartPole-v1", render_mode = "rgb_array")

experiment_name = "Cartpole_DQN"

num_episodes = 1
epsilon = 0.0
seed = config["xtra"]["seed"]

record_experiment(model_path, experiment_name, env, num_episodes, epsilon, seed)
# Out:
# c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode 1 | Total reward: 500.0
