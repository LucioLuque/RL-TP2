# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import gymnasium as gym
import yaml
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))


from utils_dqn import *

# %%
with open("../config/dqn_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
env = gym.make("CartPole-v1", render_mode = None)

print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %%
# experiment_folder = "cartpole"
# # episodes = config[experiment_folder]["episodes"]
# # buffer_size = config[experiment_folder]["buffer_size"]
# # max_steps = config[experiment_folder]["max_steps"]
# # gamma = config[experiment_folder]["gamma"]
# # alpha = config[experiment_folder]["alpha"]
# # target_update_freq = config[experiment_folder]["target_update_freq"]
# # min_epsilon = config[experiment_folder]["min_epsilon"]
# # max_epsilon = config[experiment_folder]["max_epsilon"]
# # decay_rate = config[experiment_folder]["decay_rate"]
# # batch_size = config[experiment_folder]["batch_size"]
# seed = config["xtra"]["seed"]

# import json

# successful_trials = []

# with open("successful_trials.jsonl", "r") as f:

#     for line in f:

#         trial_data = json.loads(line)

#         successful_trials.append(trial_data)

# paths = []
# for trial in successful_trials:

#     trial_number = trial["trial_number"]

#     hparams = trial["hparams"]


#     model_path, _ = train_dqn(experiment_folder, env, seed=seed, **hparams)
#     paths.append(model_path)
#     env = gym.make("CartPole-v1", render_mode = None)

#     success_rate, rewards_mean = evaluate_dqn(model_path, env, episodes=100, seed=seed)
#     print(f"Success rate: {success_rate:.2f}")
#     print(f"Mean rewards: {rewards_mean:.2f}")



# # model_path, _ = train_dqn(experiment_folder, env, episodes, buffer_size, max_steps,
# #                             gamma, alpha, target_update_freq, min_epsilon, max_epsilon, decay_rate, batch_size, seed)


# Experiment ../runs/dqn/cartpole/epi_200_buf_4936_steps_500_g_0.9705108950535776_lr_0.001757554333451538_target_200_eps_0.03131167369864196_max_eps_1.0_decay_0.0021839622514341107_batch_64 already exists.
# Success rate: 1.00
# Mean rewards: 500.00
# Experiment ../runs/dqn/cartpole/epi_200_buf_1413_steps_500_g_0.9836175774731484_lr_0.0018005418270375267_target_600_eps_0.040588267434185095_max_eps_1.0_decay_0.05262779049970934_batch_64 already exists.
# Success rate: 1.00
# Mean rewards: 500.00
# Experiment ../runs/dqn/cartpole/epi_200_buf_19418_steps_500_g_0.9623697757488063_lr_0.003592422201640305_target_650_eps_0.034533810977999214_max_eps_1.0_decay_0.014549392296859441_batch_64 already exists.
# Success rate: 1.00
# Mean rewards: 500.00
# Experiment ../runs/dqn/cartpole/epi_200_buf_19174_steps_500_g_0.9646681721785848_lr_0.0030620120803797257_target_650_eps_0.06885521919674426_max_eps_1.0_decay_0.0057584175735374945_batch_64 already exists.
# Success rate: 1.00
# Mean rewards: 500.00
# Experiment ../runs/dqn/cartpole/epi_200_buf_17881_steps_500_g_0.9673559464069645_lr_0.007871071779143148_target_650_eps_0.06615526793323716_max_eps_1.0_decay_0.005616009739503348_batch_64 already exists.
# Success rate: 1.00
# Mean rewards: 500.00

# %%
experiment_folder = "cartpole"
# params = config["cartpole_2"]
params = config["cartpole"]
seed = config["xtra"]["seed"]

model_path, _, _ = train_dqn(experiment_folder, env, seed=seed, **params)
# Out:
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# /home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# /home/alumno1/Documents/RL-TP2/models/dqn.py:86: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   return torch.as_tensor(states, dtype=torch.float32, device=self.device)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 params = config["cartpole"]
#       4 seed = config["xtra"]["seed"]
# ----> 6 model_path, _, _ = train_dqn(experiment_folder, env, seed=seed, **params)
#
# File ~/Documents/RL-TP2/src/utils_dqn.py:37, in train_dqn(experiment_folder, env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, batch_size, seed, save, log_q_values, trial)
#      34 log_dir = path if save else None
#      36 dqn_model = DQN(env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, log_dir)
# ---> 37 training_results = dqn_model.train(batch_size, seed, log_q_values, trial)
#      38 if save:
#      39     dqn_model.q_net.save(model_path)
#
# File ~/Documents/RL-TP2/models/dqn.py:229, in DQN.train(self, batch_size, seed, log_q_values, trial, report_freq)
#     227 bar = tqdm(range(self.episodes), desc="Training DQN")
#     228 for episode in bar:
# --> 229     total_reward, reward_per_step, mean_loss, episode_steps = self.run_episode(episode, batch_size, seed)
#     230     self.scheduler.step()
#     232     self.total_steps += episode_steps
#
# File ~/Documents/RL-TP2/models/dqn.py:178, in DQN.run_episode(self, episode, batch_size, seed)
#     174 done = terminated or truncated
#     176 self.replay_buffer.update((state, action, reward, next_state, done))
# --> 178 loss = self.update(batch_size)
#     180 if loss is not None:
#     181     losses.append(loss)
#
# File ~/Documents/RL-TP2/models/dqn.py:104, in DQN.update(self, batch_size)
#     101 states, actions, rewards, next_states, dones = zip(*batch)
#     103 states_tensor = self.obs_to_tensor(states)
# --> 104 actions_tensor = torch.tensor(actions, dtype=torch.long, device=self.device)
#     105 next_states_tensor = self.obs_to_tensor(next_states)
#     106 rewards_tensor = torch.tensor(rewards, dtype=torch.float32, device=self.device)
#
# KeyboardInterrupt:

# %%
env = gym.make("CartPole-v1", render_mode = None)

success_rate, rewards_mean = evaluate_dqn(model_path, env, episodes=100, seed=seed)
print(f"Success rate: {success_rate:.2f}")
print(f"Mean rewards: {rewards_mean:.2f}")

# %%
env = gym.make("CartPole-v1", render_mode = "rgb_array")

experiment_name = "Cartpole_DQN"

num_episodes = 1
epsilon = 0.0
seed = config["xtra"]["seed"]

record_experiment(model_path, experiment_name, env, num_episodes, epsilon, seed)

# %%
# Success rate: 0.70
# Mean rewards: 450.04

# # cartpole:
#   episodes: 200
#   buffer_size: 10000
#   max_steps: 500
#   gamma: 0.99
#   lr: 0.0001
#   target_update_freq: 500
#   min_epsilon: 0.05
#   max_epsilon: 1.0
#   decay_rate: 0.001
#   batch_size: 64
