# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import gymnasium as gym
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from dqn_optuna import hyperparameter_search

# %%
from pathlib import Path

BASE_DIR = Path("../dqn_hyperparams")
BASE_DIR.mkdir(exist_ok=True)

study = hyperparameter_search(
    env_id="CartPole-v1",

    experiment_folder="cartpole_optuna",

    n_trials=50,

    seed=42,

    fixed={
        "max_steps": 500,
        "max_epsilon": 1.0,
    },

    storage=f"sqlite:///{BASE_DIR / 'optuna_dqn.db'}",

    results_path=str(BASE_DIR / "hparam_results.json"),

    all_trials_path=str(BASE_DIR / "all_trials.jsonl"),

    converged_trials_path=str(BASE_DIR / "converged_trials.jsonl"),

    show_plots=True,
)
# Out:
# [I 2026-05-19 17:34:46,759] A new study created in RDB with name: dqn_cartpole_v1
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# /home/alumno1/Documents/RL-TP2/models/dqn.py:79: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   return torch.as_tensor(states, dtype=torch.float32, device=self.device)
# Trial 0 | Score=242.19 | FinalAvg=178.65 | Std=65.38
# [I 2026-05-19 17:35:35,755] Trial 0 finished with value: 242.1948916648416 and parameters: {'lr': 0.0005611516415334506, 'target_update_freq': 700, 'min_epsilon': 0.07587945476302646, 'decay_rate': 0.015751320499779727, 'batch_size': 32}. Best is trial 0 with value: 242.1948916648416.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 1 | Score=28.20 | FinalAvg=25.60 | Std=11.86
# [I 2026-05-19 17:35:42,880] Trial 1 finished with value: 28.20224790071034 and parameters: {'lr': 0.005399484409787433, 'target_update_freq': 450, 'min_epsilon': 0.0737265320016441, 'decay_rate': 0.0010994335574766201, 'batch_size': 32}. Best is trial 0 with value: 242.1948916648416.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 2 | Score=270.60 | FinalAvg=289.10 | Std=61.67
# [I 2026-05-19 17:36:40,393] Trial 2 finished with value: 270.5982676486768 and parameters: {'lr': 0.0002310201887845295, 'target_update_freq': 150, 'min_epsilon': 0.0373818018663584, 'decay_rate': 0.01120760621186057, 'batch_size': 128}. Best is trial 2 with value: 270.5982676486768.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 3 | Score=304.86 | FinalAvg=320.95 | Std=63.71
# [I 2026-05-19 17:37:20,853] Trial 3 finished with value: 304.8570390833864 and parameters: {'lr': 0.00019010245319870352, 'target_update_freq': 250, 'min_epsilon': 0.04297256589643226, 'decay_rate': 0.008168455894760165, 'batch_size': 32}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 4 | Score=32.94 | FinalAvg=37.70 | Std=27.00
# [I 2026-05-19 17:37:31,590] Trial 4 finished with value: 32.93938891194004 and parameters: {'lr': 0.0015304852121831463, 'target_update_freq': 50, 'min_epsilon': 0.06467903667112945, 'decay_rate': 0.002193048555664369, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 5 | Score=235.01 | FinalAvg=279.70 | Std=148.97
# [I 2026-05-19 17:38:21,005] Trial 5 finished with value: 235.0102595666522 and parameters: {'lr': 0.004138040112561018, 'target_update_freq': 250, 'min_epsilon': 0.018790490260574548, 'decay_rate': 0.0233596350262616, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 6 | Score=34.40 | FinalAvg=31.75 | Std=19.96
# [I 2026-05-19 17:38:27,783] Trial 6 finished with value: 34.39543929619474 and parameters: {'lr': 0.00011715937392307068, 'target_update_freq': 650, 'min_epsilon': 0.03329019834400153, 'decay_rate': 0.02113705944064573, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 7 | Score=21.81 | FinalAvg=19.30 | Std=5.90
# [I 2026-05-19 17:38:32,838] Trial 7 finished with value: 21.81 and parameters: {'lr': 0.00023426581058204064, 'target_update_freq': 700, 'min_epsilon': 0.07976195410250031, 'decay_rate': 0.0756829206016762, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 8 | Score=156.31 | FinalAvg=173.30 | Std=56.62
# [I 2026-05-19 17:38:55,465] Trial 8 finished with value: 156.31297848355987 and parameters: {'lr': 0.00015030900645056822, 'target_update_freq': 150, 'min_epsilon': 0.014070456001948426, 'decay_rate': 0.004473636174621266, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 9 | Score=32.12 | FinalAvg=40.20 | Std=29.42
# [I 2026-05-19 17:39:05,191] Trial 9 finished with value: 32.1154093579362 and parameters: {'lr': 0.0005170191786366995, 'target_update_freq': 200, 'min_epsilon': 0.058842647484242366, 'decay_rate': 0.00191358804876923, 'batch_size': 128}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 110
# [I 2026-05-19 17:39:10,895] Trial 10 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 11 | Score=193.43 | FinalAvg=181.60 | Std=25.97
# [I 2026-05-19 17:39:47,762] Trial 11 finished with value: 193.42900519830746 and parameters: {'lr': 0.00031991905840069384, 'target_update_freq': 300, 'min_epsilon': 0.03928239981741564, 'decay_rate': 0.007289119112150237, 'batch_size': 32}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 110
# [I 2026-05-19 17:39:50,038] Trial 12 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 13 | Score=249.08 | FinalAvg=250.35 | Std=73.51
# [I 2026-05-19 17:40:42,101] Trial 13 finished with value: 249.07820925638916 and parameters: {'lr': 0.00028483995480093287, 'target_update_freq': 500, 'min_epsilon': 0.04825054647004666, 'decay_rate': 0.010789999443763984, 'batch_size': 32}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 14 | Score=110.96 | FinalAvg=87.35 | Std=42.90
# [I 2026-05-19 17:41:13,502] Trial 14 finished with value: 110.9595891673964 and parameters: {'lr': 0.002023048619894484, 'target_update_freq': 300, 'min_epsilon': 0.026610415364311864, 'decay_rate': 0.03792749263052181, 'batch_size': 32}. Best is trial 3 with value: 304.8570390833864.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 15 | Score=348.17 | FinalAvg=384.20 | Std=120.09
# [I 2026-05-19 17:42:16,726] Trial 15 finished with value: 348.17206084161904 and parameters: {'lr': 0.000564895267285297, 'target_update_freq': 150, 'min_epsilon': 0.05177043361231179, 'decay_rate': 0.009714046380046689, 'batch_size': 64}. Best is trial 15 with value: 348.17206084161904.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 100
# [I 2026-05-19 17:42:22,688] Trial 16 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 190
# [I 2026-05-19 17:42:53,578] Trial 17 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 100
# [I 2026-05-19 17:42:57,132] Trial 18 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 110
# [I 2026-05-19 17:43:04,665] Trial 19 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 20 | Score=216.30 | FinalAvg=226.80 | Std=36.61
# [I 2026-05-19 17:43:52,927] Trial 20 finished with value: 216.29795101085415 and parameters: {'lr': 0.0004374741748886459, 'target_update_freq': 100, 'min_epsilon': 0.09588067337900183, 'decay_rate': 0.015610782649559266, 'batch_size': 32}. Best is trial 15 with value: 348.17206084161904.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 21 | Score=269.11 | FinalAvg=245.85 | Std=52.05
# [I 2026-05-19 17:44:52,346] Trial 21 finished with value: 269.11406342866366 and parameters: {'lr': 0.0001893163195977775, 'target_update_freq': 200, 'min_epsilon': 0.03661303772097388, 'decay_rate': 0.00970198920764305, 'batch_size': 128}. Best is trial 15 with value: 348.17206084161904.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 22 | Score=299.02 | FinalAvg=318.00 | Std=63.28
# [I 2026-05-19 17:45:42,062] Trial 22 finished with value: 299.0156643518926 and parameters: {'lr': 0.0003064527767000974, 'target_update_freq': 150, 'min_epsilon': 0.029536447846392512, 'decay_rate': 0.010626524712005543, 'batch_size': 32}. Best is trial 15 with value: 348.17206084161904.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 140
# [I 2026-05-19 17:46:02,055] Trial 23 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 80
# [I 2026-05-19 17:46:05,334] Trial 24 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial pruned at episode 80
# [I 2026-05-19 17:46:07,627] Trial 25 pruned.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 26 | Score=397.91 | FinalAvg=430.05 | Std=107.15
# [I 2026-05-19 17:47:15,234] Trial 26 finished with value: 397.9056649625474 and parameters: {'lr': 0.00039315587588743074, 'target_update_freq': 100, 'min_epsilon': 0.01110303260141654, 'decay_rate': 0.025777783527467433, 'batch_size': 32}. Best is trial 26 with value: 397.9056649625474.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 27 | Score=432.63 | FinalAvg=451.65 | Std=115.99
# [I 2026-05-19 17:48:43,145] Trial 27 finished with value: 432.6316455130418 and parameters: {'lr': 0.00042573611162247707, 'target_update_freq': 50, 'min_epsilon': 0.01232918421263584, 'decay_rate': 0.02836120623174777, 'batch_size': 64}. Best is trial 27 with value: 432.6316455130418.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 28 | Score=285.37 | FinalAvg=273.80 | Std=238.11
# [I 2026-05-19 17:50:21,412] Trial 28 finished with value: 285.36826755565846 and parameters: {'lr': 0.0011879063278155853, 'target_update_freq': 50, 'min_epsilon': 0.0130098918359237, 'decay_rate': 0.037721376725266216, 'batch_size': 64}. Best is trial 27 with value: 432.6316455130418.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# [W 2026-05-19 17:50:32,917] Trial 29 failed with parameters: {'lr': 0.0006576610812351349, 'target_update_freq': 100, 'min_epsilon': 0.01104588654647979, 'decay_rate': 0.024207118330675362, 'batch_size': 64} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/home/alumno1/Documents/RL-TP2/src/dqn_optuna.py", line 103, in objective
#     model_path, model_params, training_stats = train_dqn(
#                                                ^^^^^^^^^^
#   File "/home/alumno1/Documents/RL-TP2/src/utils_dqn.py", line 37, in train_dqn
#     training_results = dqn_model.train(batch_size, seed, log_q_values, trial)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumno1/Documents/RL-TP2/models/dqn.py", line 190, in train
#     total_reward, reward_per_step, mean_loss, episode_steps = self.run_episode(episode, batch_size, seed)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumno1/Documents/RL-TP2/models/dqn.py", line 137, in run_episode
#     loss = self.update(batch_size)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumno1/Documents/RL-TP2/models/dqn.py", line 110, in update
#     loss.backward()
#   File "/home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/torch/_tensor.py", line 626, in backward
#     torch.autograd.backward(
#   File "/home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/home/alumno1/miniconda3/envs/vision/lib/python3.11/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2026-05-19 17:50:32,918] Trial 29 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 BASE_DIR = Path("../dqn_hyperparams")
#       4 BASE_DIR.mkdir(exist_ok=True)
# ----> 6 study = hyperparameter_search(
#       7     env_id="CartPole-v1",
#       8
#       9     experiment_folder="cartpole_optuna",
#      10
#      11     n_trials=50,
#      12
#      13     seed=42,
#      14
#      15     fixed={
#      16         "max_steps": 500,
#      17         "max_epsilon": 1.0,
#      18     },
#      19
#      20     storage=f"sqlite:///{BASE_DIR / 'optuna_dqn.db'}",
#      21
#      22     results_path=str(BASE_DIR / "hparam_results.json"),
#      23
#      24     all_trials_path=str(BASE_DIR / "all_trials.jsonl"),
#      25
#      26     converged_trials_path=str(BASE_DIR / "converged_trials.jsonl"),
#      27
#      28     show_plots=True,
#      29 )
#
# File ~/Documents/RL-TP2/src/dqn_optuna.py:241, in hyperparameter_search(env_id, experiment_folder, n_trials, seed, fixed, study_name, storage, n_jobs, show_plots, results_path, all_trials_path, converged_trials_path)
#     223 study = optuna.create_study(
#     224     direction="maximize",
#     225     sampler=sampler,
#    (...)    229     load_if_exists=True,
#     230 )
#     232 objective = make_objective(
#     233     env_id=env_id,
#     234     experiment_folder=experiment_folder,
#    (...)    238     converged_trials_path = converged_trials_path,
#     239 )
# --> 241 study.optimize(
#     242     objective,
#     243     n_trials=n_trials,
#     244     n_jobs=n_jobs,
#     245     show_progress_bar=True,
#     246 )
#     248 print("\n" + "=" * 60)
#     249 print(f"  Mejores hiperparámetros ({study_name})")
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File ~/Documents/RL-TP2/src/dqn_optuna.py:103, in make_objective.<locals>.objective(trial)
#      99 env = gym.make(env_id)
#     101 try:
# --> 103     model_path, model_params, training_stats = train_dqn(
#     104         experiment_folder=experiment_folder,
#     105         env=env,
#     106         seed=seed,
#     107         save=False,
#     108         log_q_values=False,
#     109         trial=trial,
#     110         **hparams,
#     111     )
#     113 except optuna.exceptions.TrialPruned:
#     115     raise
#
# File ~/Documents/RL-TP2/src/utils_dqn.py:37, in train_dqn(experiment_folder, env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, batch_size, seed, save, log_q_values, trial)
#      34 log_dir = path if save else None
#      36 dqn_model = DQN(env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, log_dir)
# ---> 37 training_results = dqn_model.train(batch_size, seed, log_q_values, trial)
#      38 if save:
#      39     dqn_model.q_net.save(model_path)
#
# File ~/Documents/RL-TP2/models/dqn.py:190, in DQN.train(self, batch_size, seed, log_q_values, trial, report_freq)
#     188 bar = tqdm(range(self.episodes), desc="Training DQN")
#     189 for episode in bar:
# --> 190     total_reward, reward_per_step, mean_loss, episode_steps = self.run_episode(episode, batch_size, seed)
#     191     self.total_steps += episode_steps
#     193     reward_history.append(total_reward)
#
# File ~/Documents/RL-TP2/models/dqn.py:137, in DQN.run_episode(self, episode, batch_size, seed)
#     133 done = terminated or truncated
#     135 self.replay_buffer.update((state, action, reward, next_state, done))
# --> 137 loss = self.update(batch_size)
#     139 if loss is not None:
#     140     losses.append(loss)
#
# File ~/Documents/RL-TP2/models/dqn.py:110, in DQN.update(self, batch_size)
#     108 loss = F.mse_loss(q_values, target_q_values)
#     109 self.optimizer.zero_grad()
# --> 110 loss.backward()
#     111 self.optimizer.step()
#     113 self.updates += 1
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/vision/lib/python3.11/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:
