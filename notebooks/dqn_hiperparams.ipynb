# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import gymnasium as gym
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from dqn_optuna import hyperparameter_search

# %%
study = hyperparameter_search(
        env_id="CartPole-v1",
        experiment_folder="cartpole_optuna",
        n_trials=30,
        eval_episodes=50,
        seed=42,
        fixed={
            "max_steps": 500,
            "max_epsilon": 1.0,
        },
            # storage="sqlite:///optuna_dqn.db",  # descomentá para persistencia entre runs
        show_plots=True,
    )
# Out:
# [I 2026-05-19 14:07:40,915] A new study created in memory with name: dqn_cartpole_v1
#   0%|          | 0/30 [00:00<?, ?it/s]
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py:78: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   return torch.as_tensor(states, dtype=torch.float32, device=self.device)
# [I 2026-05-19 14:08:06,877] Trial 0 finished with value: -inf and parameters: {'buffer_size': 4327, 'gamma': 0.9941207163345817, 'lr': 0.0029106359131330704, 'target_update_freq': 450, 'min_epsilon': 0.02404167763981929, 'decay_rate': 0.002051110418843397, 'batch_size': 64}. Best is trial 0 with value: -inf.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# [W 2026-05-19 14:08:16,840] Trial 1 failed with parameters: {'buffer_size': 15956, 'gamma': 0.9020378649352845, 'lr': 0.008706020878304856, 'target_update_freq': 600, 'min_epsilon': 0.029110519961044856, 'decay_rate': 0.0023102018878452934, 'batch_size': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\dqn_optuna.py", line 52, in objective
#     model_path, model_params = train_dqn(
#                                ^^^^^^^^^^
#   File "c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\utils_dqn.py", line 36, in train_dqn
#     dqn_model.train(batch_size, seed, log_q_values)
#   File "c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py", line 185, in train
#     total_reward, reward_per_step, mean_loss, episode_steps = self.run_episode(episode, batch_size, seed)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py", line 136, in run_episode
#     loss = self.update(batch_size)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py", line 110, in update
#     self.optimizer.step()
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py", line 526, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py", line 81, in _use_grad
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py", line 248, in step
#     adam(
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py", line 151, in maybe_fallback
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py", line 970, in adam
#     func(
#   File "c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py", line 431, in _single_tensor_adam
#     if torch.is_complex(param):
#        ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2026-05-19 14:08:16,845] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 study = hyperparameter_search(
#       2         env_id="CartPole-v1",
#       3         experiment_folder="cartpole_optuna",
#       4         n_trials=30,
#       5         eval_episodes=50,
#       6         seed=42,
#       7         fixed={
#       8             "max_steps": 500,
#       9             "max_epsilon": 1.0,
#      10         },
#      11             # storage="sqlite:///optuna_dqn.db",  # descomentá para persistencia entre runs
#      12         show_plots=True,
#      13     )
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\dqn_optuna.py:165, in hyperparameter_search(env_id, experiment_folder, n_trials, eval_episodes, seed, fixed, study_name, storage, n_jobs, show_plots, results_path, successful_trials_path)
#     147 study = optuna.create_study(
#     148     direction="maximize",
#     149     sampler=sampler,
#    (...)    153     load_if_exists=True,              # reanuda si ya existe en storage
#     154 )
#     156 objective = make_objective(
#     157     env_id=env_id,
#     158     experiment_folder=experiment_folder,
#    (...)    162     successful_trials_path=successful_trials_path,
#     163 )
# --> 165 study.optimize(
#     166     objective,
#     167     n_trials=n_trials,
#     168     n_jobs=n_jobs,
#     169     show_progress_bar=True,
#     170 )
#     172 print("\n" + "="*60)
#     173 print(f"  Mejores hiperparámetros ({study_name})")
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\dqn_optuna.py:52, in make_objective.<locals>.objective(trial)
#      49 env = gym.make(env_id)
#      51 try:
# ---> 52     model_path, model_params = train_dqn(
#      53         experiment_folder=trial_folder,
#      54         env=env,
#      55         seed=seed,
#      56         save=False,
#      57         log_q_values=False,
#      58         **hparams,
#      59     )
#      61     eval_env = gym.make(env_id)
#      62     success_rate, mean_reward = evaluate_dqn_model(
#      63         path=model_path,
#      64         env=eval_env,
#    (...)     67         seed=seed,
#      68     )
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\src\utils_dqn.py:36, in train_dqn(experiment_folder, env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, batch_size, seed, save, log_q_values)
#      33 log_dir = path if save else None
#      35 dqn_model = DQN(env, episodes, buffer_size, max_steps, gamma, lr, target_update_freq, min_epsilon, max_epsilon, decay_rate, log_dir)
# ---> 36 dqn_model.train(batch_size, seed, log_q_values)
#      37 if save:
#      38     dqn_model.q_net.save(model_path)
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py:185, in DQN.train(self, batch_size, seed, log_q_values)
#     183 bar = tqdm(range(self.episodes), desc="Training DQN")
#     184 for episode in bar:
# --> 185     total_reward, reward_per_step, mean_loss, episode_steps = self.run_episode(episode, batch_size, seed)
#     186     self.total_steps += episode_steps
#     187     if hasattr(self, 'writer'):
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py:136, in DQN.run_episode(self, episode, batch_size, seed)
#     132 done = terminated or truncated
#     134 self.replay_buffer.update((state, action, reward, next_state, done))
# --> 136 loss = self.update(batch_size)
#     138 if loss is not None:
#     139     losses.append(loss)
#
# File c:\Users\Lucio\Documents\Semestre 1\Aprendizaje reforzado\TPs\RL-TP2\models\dqn.py:110, in DQN.update(self, batch_size)
#     108 self.optimizer.zero_grad()
#     109 loss.backward()
# --> 110 self.optimizer.step()
#     112 self.updates += 1
#     113 if self.updates % self.target_update_freq == 0:
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\optimizer.py:151, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     149     return disabled_func(*args, **kwargs)
#     150 else:
# --> 151     return func(*args, **kwargs)
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File c:\Users\Lucio\miniconda3\envs\RL\Lib\site-packages\torch\optim\adam.py:431, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     428         else:
#     429             grad = grad.add(param, alpha=weight_decay)
# --> 431 if torch.is_complex(param):
#     432     grad = torch.view_as_real(grad)
#     433     exp_avg = torch.view_as_real(exp_avg)
#
# KeyboardInterrupt:
