# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import gymnasium as gym
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

sys.path.append(os.path.abspath("../envs"))
sys.path.append(os.path.abspath("../models"))
sys.path.append(os.path.abspath("../src"))

from dqn_optuna import hyperparameter_search

# %%
from pathlib import Path

BASE_DIR = Path("../dqn_hyperparams")
BASE_DIR.mkdir(exist_ok=True)

study = hyperparameter_search(
    env_id="CartPole-v1",

    experiment_folder="cartpole_optuna",

    n_trials=100,

    seed=42,

    fixed={
        "max_steps": 500,
        "max_epsilon": 1.0,
    },

    storage=f"sqlite:///{BASE_DIR / 'optuna_dqn.db'}",

    results_path=str(BASE_DIR / "hparam_results.json"),

    all_trials_path=str(BASE_DIR / "all_trials.jsonl"),

    converged_trials_path=str(BASE_DIR / "converged_trials.jsonl"),

    show_plots=True,
)
# Out:
# [I 2026-05-20 14:25:05,755] Using an existing study with name 'dqn_cartpole_v1' instead of creating a new one.
# ...
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 86 | Score=180.63 | FinalAvg=128.35 | Std=64.99
# [I 2026-05-20 14:25:35,650] Trial 86 finished with value: 180.6331675649607 and parameters: {'lr': 0.00031184865600685353, 'target_update_freq': 300, 'min_epsilon': 0.044726667211249335, 'decay_rate': 0.016249449748681716, 'batch_size': 64}. Best is trial 59 with value: 300.9588473717374.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 87 | Score=184.07 | FinalAvg=181.85 | Std=39.99
# [I 2026-05-20 14:26:04,991] Trial 87 finished with value: 184.07327232117024 and parameters: {'lr': 0.00031293769501957754, 'target_update_freq': 300, 'min_epsilon': 0.04557499484924707, 'decay_rate': 0.01565175104011195, 'batch_size': 64}. Best is trial 59 with value: 300.9588473717374.
# Training DQN:   0%|          | 0/200 [00:00<?, ?it/s]
# ...
